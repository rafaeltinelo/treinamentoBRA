# %% [markdown]
# ### 1. Some todos os números de 1 até 100

# %%
range(100)
list(range(100))
n_elementos = 100
soma = 0

for i in range(1,n_elementos+1):
    soma += i

print(soma)
# Out:
# 5050

# %% [markdown]
# ### 2. Some todos os números pares de 1 até 100

# %%
soma_pares = 0

for numero in range(1, 101):
    if numero % 2 == 0:
        soma_pares += numero

print(soma_pares)
# Out:
# 2550

# %% [markdown]
# ### 3. Some todos os números ímpares de 1 até 100

# %%
soma_impares = 0

for numero in range(1, 101):
    if numero % 2 != 0:
        soma_impares += numero

print(soma_impares)
# Out:
# 2500

# %% [markdown]
# ### 4. Dada a lista abaixo, some todos os elementos inteiros positivos

# %%
lista = [-2, 2, 'celular', 10, -99, False]
lista
# Out:
# Out[15]: [-2, 2, 'celular', 10, -99, False]

# %%
soma_positivos = 0

for elemento in lista: 
    if (isinstance(elemento, int)) and (elemento > 0):
        soma_positivos += elemento
        
print(soma_positivos)
# Out:
# 12

# %% [markdown]
# ### 5. Dada a String

# %%
string = 'pYthOn É A mELhoR LiNguaGEM De PRoGRaMaçãO'
string
# Out:
# Out[1]: 'pYthOn É A mELhoR LiNguaGEM De PRoGRaMaçãO'

# %% [markdown]
# Formate-a com as primeiras letras maiúsculas:

# %%
a = 'pYthOn É A mELhoR LiNguaGEM De PRoGRaMaçãO'
a.title()
# Out:
# Out[2]: 'Python É A Melhor Linguagem De Programação'

# %% [markdown]
# Com todas as letras minúsculas

# %%
a = 'pYthOn É A mELhoR LiNguaGEM De PRoGRaMaçãO'
a.lower()
# Out:
# Out[4]: 'python é a melhor linguagem de programação'

# %% [markdown]
# Com todas as letras maiúsculas

# %%
a = 'pYthOn É A mELhoR LiNguaGEM De PRoGRaMaçãO'
a.upper()
# Out:
# Out[5]: 'PYTHON É A MELHOR LINGUAGEM DE PROGRAMAÇÃO'
