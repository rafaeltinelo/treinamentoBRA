# %% [markdown]
# #PROJETO LAB DATA - BIG-BEN MULTIMARKET
# ![Logo do R](https://s1.static.brasilescola.uol.com.br/be/conteudo/images/big-ben.jpg)

# %% [markdown]
# **Danielle Faria**
#
# **Juliana Souza**
#
# **Maurício Mourão**
#
# **Rafael Talaveira**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
# Puxar a base
df = spark.read.csv("/FileStore/tables/retail.csv", header=True, sep=',', inferSchema=True)
df = df.toPandas()

# %%
# Informações do df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_no    541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  int32
#  4   invoice_date  541909 non-null  object
#  5   unit_price    541909 non-null  object
#  6   customer_id   406829 non-null  float64
#  7   region        541909 non-null  object
# dtypes: float64(1), int32(1), object(6)
# memory usage: 31.0+ MB

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2,55</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3,39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2,75</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3,39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3,39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Retirar valores com Zeros e Negativos
df_no_0 = df[df['unit_price'] > '0']
df_no_0 = df_no_0[df_no_0['quantity'] > 0]

# %%
# Verificação sem Zeros e Negativos
df_no_0.groupby('unit_price').count().sort_values('unit_price', ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#     <tr>
#       <th>unit_price</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>99,96</th>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>0</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>988</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>98,79</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>98,75</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>98,54</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>0,08</th>
#       <td>55</td>
#       <td>55</td>
#       <td>55</td>
#       <td>55</td>
#       <td>55</td>
#       <td>55</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>0,07</th>
#       <td>7</td>
#       <td>7</td>
#       <td>7</td>
#       <td>7</td>
#       <td>7</td>
#       <td>7</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>0,06</th>
#       <td>116</td>
#       <td>116</td>
#       <td>116</td>
#       <td>116</td>
#       <td>116</td>
#       <td>112</td>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>0,04</th>
#       <td>66</td>
#       <td>66</td>
#       <td>66</td>
#       <td>66</td>
#       <td>66</td>
#       <td>66</td>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th>0,001</th>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# <p>1291 rows × 7 columns</p>
# </div>

# %%
# Agrupar por região e contagem de quantidade de linhas
df_no_0.groupby('region').agg(n=('quantity', 'count')).sort_values('n', ascending=False).reset_index()
# Aqui definimos que trabalharemos só com países da Europa
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>region</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>United Kingdom</td>
#       <td>485123</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Germany</td>
#       <td>9040</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>France</td>
#       <td>8407</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>EIRE</td>
#       <td>7890</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Spain</td>
#       <td>2484</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Netherlands</td>
#       <td>2359</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Belgium</td>
#       <td>2031</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Switzerland</td>
#       <td>1966</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Portugal</td>
#       <td>1501</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Australia</td>
#       <td>1182</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Norway</td>
#       <td>1071</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Italy</td>
#       <td>758</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Channel Islands</td>
#       <td>748</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Finland</td>
#       <td>685</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Cyprus</td>
#       <td>614</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Sweden</td>
#       <td>451</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Unspecified</td>
#       <td>446</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Austria</td>
#       <td>398</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Denmark</td>
#       <td>380</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Poland</td>
#       <td>330</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Japan</td>
#       <td>321</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Israel</td>
#       <td>295</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Hong Kong</td>
#       <td>284</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Singapore</td>
#       <td>222</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Iceland</td>
#       <td>182</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>USA</td>
#       <td>179</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Canada</td>
#       <td>151</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Greece</td>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Malta</td>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>United Arab Emirates</td>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>European Community</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>RSA</td>
#       <td>57</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Lebanon</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Lithuania</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Brazil</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Czech Republic</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Bahrain</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Saudi Arabia</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Tratar virgulas para ponto para converter para Float
df_no_0['unit_price'] = df_no_0['unit_price'].apply(lambda x: float(x.replace(".","").replace(",",".")))

# %%
# Converter para Float
df_no_0['unit_price'] = df_no_0['unit_price'].astype(float)

# %%
# Multiplica o valor unitário pela quantidade de itens criando uma nova coluna
df_receita = df_no_0.assign(total_price = lambda x: x['quantity'] * x['unit_price'])

# %%
df_receita.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>15.30</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>22.00</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Filtrando apenas Europa

# %%
# Lista com os nomes de todos os países da Europa
paises_europa = ["Albania", "Andorra", "Austria", "Belarus", "Belgium", "BosniaandHerzegovina", "Bulgaria", "Croatia", "Cyprus", "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Kosovo", "Latvia", "Liechtenstein", "Lithuania", "Luxembourg", "Malta", "Moldova", "Monaco", "Montenegro", "Netherlands", "NorthMacedonia", "Norway", "Poland", "Portugal", "Romania", "Russia", "SanMarino", "Serbia", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Ukraine", "United Kingdom", "VaticanCity", "EIRE", "European Community", "Channel Islands"]

# %%
# Cria a coluna continent e colocar Europa nos paises da Europa e Outros nos demais
df_receita.insert(9, 'continent', '')

# %%
df_receita['continent'] = df_receita['region'].apply(lambda x: 'Europa' if x in paises_europa else 'Outros Continentes')

# %%
# Tirar as duplicadas para a contagem
df_no_duplicates = df_receita[['invoice_no', 'region', 'continent']].drop_duplicates()
df_no_duplicates.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>region</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>United Kingdom</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>536366</td>
#       <td>United Kingdom</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>536367</td>
#       <td>United Kingdom</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>United Kingdom</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>536369</td>
#       <td>United Kingdom</td>
#       <td>Europa</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Mostrar valores por continentes
df_nums = df_no_duplicates.groupby('continent').agg(n=('continent', 'count')).sort_values('n', ascending=False).reset_index()

df_nums.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>continent</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Europa</td>
#       <td>19824</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Outros Continentes</td>
#       <td>136</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Representação gráfica em porcentagem
plt.pie(df_nums['n'], labels = df_nums['continent'], autopct='%.0f%%')
plt.title('VENDAS POR CONTINENTE')
plt.show()

# %%
# Filtrou apenas peises da Europa
df_europe = df_receita[df_receita['continent'] == "Europa"]
df_europe.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>15.30</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>22.00</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>Europa</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Pedidos por país Europa
df_paises_europa = df_europe.groupby('region').agg(n=('invoice_no', 'count')).sort_values('n', ascending=False).reset_index()
df_paises_europa.head(30)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>region</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>United Kingdom</td>
#       <td>485123</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Germany</td>
#       <td>9040</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>France</td>
#       <td>8407</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>EIRE</td>
#       <td>7890</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Spain</td>
#       <td>2484</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Netherlands</td>
#       <td>2359</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Belgium</td>
#       <td>2031</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Switzerland</td>
#       <td>1966</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Portugal</td>
#       <td>1501</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Norway</td>
#       <td>1071</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Italy</td>
#       <td>758</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Channel Islands</td>
#       <td>748</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Finland</td>
#       <td>685</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Cyprus</td>
#       <td>614</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Sweden</td>
#       <td>451</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Austria</td>
#       <td>398</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Denmark</td>
#       <td>380</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Poland</td>
#       <td>330</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Iceland</td>
#       <td>182</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Greece</td>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Malta</td>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>European Community</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Lithuania</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Czech Republic</td>
#       <td>25</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Plot pedidos por país Europa
fig, ax = plt.subplots(figsize=(15, 8))

graph7 = sns.barplot(data=df_paises_europa, y='region', x='n', ax=ax);
ax.set_ylabel('País', fontsize=13);
ax.set_xlabel('Quantidade', fontsize=13);
ax.set_title('Pedidos por País', fontsize=20);

# %% [markdown]
# ## Gráficos

# %% [markdown]
# #### Produtos Mais Vendidos

# %%
# Separar código e produto para plotagem
df_produtos = df_europe.groupby(['stock_code', 'description']).agg(n=('stock_code', 'count')).sort_values('n', ascending=False).reset_index()

# %%
# Top 10 produtos mais comprados
df_produtos_10p = df_produtos.nlargest(10, 'n')

df_produtos_10p.head(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>2251</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>85099B</td>
#       <td>JUMBO BAG RED RETROSPOT</td>
#       <td>2104</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>22423</td>
#       <td>REGENCY CAKESTAND 3 TIER</td>
#       <td>1995</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>47566</td>
#       <td>PARTY BUNTING</td>
#       <td>1690</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20725</td>
#       <td>LUNCH BAG RED RETROSPOT</td>
#       <td>1580</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>84879</td>
#       <td>ASSORTED COLOUR BIRD ORNAMENT</td>
#       <td>1485</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>22720</td>
#       <td>SET OF 3 CAKE TINS PANTRY DESIGN</td>
#       <td>1386</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>21212</td>
#       <td>PACK OF 72 RETROSPOT CAKE CASES</td>
#       <td>1362</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>20727</td>
#       <td>LUNCH BAG  BLACK SKULL.</td>
#       <td>1322</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>22457</td>
#       <td>NATURAL SLATE HEART CHALKBOARD</td>
#       <td>1261</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Plotagem por nome do produto
fig, ax = plt.subplots(figsize=(15, 8))

graph = sns.barplot(data=df_produtos_10p, y='description', x='n', ax=ax);
ax.set_ylabel('Descrição', fontsize=13);
ax.set_xlabel('Quantidade', fontsize=13);
ax.set_title('Produtos Mais Vendidos', fontsize=20);

# %%
# Plotagem por código
fig, ax = plt.subplots(figsize=(15, 6))

graph2 = sns.barplot(data=df_produtos_10p, x='stock_code', y='n', ax=ax);
ax.set_ylabel('Quantidade', fontsize=13);
ax.set_xlabel('Código do Produto', fontsize=13);
ax.set_title('Produtos Mais Vendidos', fontsize=20);

# %% [markdown]
# ####Valor Total por Venda

# %%
# Selecionar colunas para o grafico
df_pedidos = df_europe[['invoice_no', 'quantity', 'total_price']]

# %%
# Somar quantidade e valores por pedido
df_out = df_pedidos.groupby(['invoice_no']).sum().sort_values('total_price', ascending=False).reset_index()
df_out.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>quantity</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>581483</td>
#       <td>80995</td>
#       <td>168469.60</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>541431</td>
#       <td>74215</td>
#       <td>77183.60</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>574941</td>
#       <td>14149</td>
#       <td>52940.94</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>576365</td>
#       <td>13956</td>
#       <td>50653.91</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>556444</td>
#       <td>60</td>
#       <td>38970.00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Plotagem do gráfico
sns.lmplot(
    data=df_out, x="quantity", y="total_price",
    facet_kws=dict(sharex=False, sharey=False) 
)
plt.title('VALOR TOTAL POR VENDA')
plt.xlabel('Quantidade')
plt.ylabel('Valor');
# Existem alguns pedidos que os valores estão destuando dos valores médios

# %% [markdown]
# ####Identificar Consumo por Cliente

# %%
df_europe.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>15.30</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>22.00</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>Europa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>Europa</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Pegando colunas necesarias
df_cliente = df_europe[['customer_id', 'total_price']]

# %%
# Somar quantidade e valores por pedido
df_valor_cliente = df_cliente.groupby(['customer_id']).sum().sort_values('total_price', ascending=False).reset_index()
df_valor_cliente.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14646.0</td>
#       <td>280206.02</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18102.0</td>
#       <td>259657.30</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17450.0</td>
#       <td>194550.79</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16446.0</td>
#       <td>168472.50</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14911.0</td>
#       <td>143825.06</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Plotagem do gráfico de clientes
sns.lmplot(
    data = df_valor_cliente, x="customer_id", y="total_price",
    facet_kws=dict(sharex=False, sharey=False) 
)
plt.title('VALOR GASTO POR CLIENTE')
plt.xlabel('Cliente')
plt.ylabel('Valor');

# %% [markdown]
# ![Logo do R](https://s1.static.brasilescola.uol.com.br/be/conteudo/images/big-ben.jpg)

# %% [markdown]
# ##Análise de vendas por região
# > Definição de nova estratégia em relação ao território de vendas<br>
# > Redução de custos a partir do encerramento de atividades em regiões com baixa demanda<br>
# > Atendimento focado para países da Europa

# %%
# Representação gráfica em porcentagem
plt.pie(df_nums['n'], labels = df_nums['continent'], autopct='%.0f%%')
plt.title('VENDAS POR CONTINENTE')
plt.show()

# %% [markdown]
# ##Pedidos por país
# > Centro de distribuição no Reino Unido, possibilitando entregas mais rápidas para o país mais demandante e facilitando o acesso aos demais <br>
# > Criação de campanhas para aumentar o volume de vendas no top 3 países que mais vendem, após o Reino Unido (Alemanha, França e Irlanda)

# %%
# Plot pedidos por país Europa
fig, ax = plt.subplots(figsize=(15, 8))

graph7 = sns.barplot(data=df_paises_europa, y='region', x='n', ax=ax);
ax.set_ylabel('País', fontsize=13);
ax.set_xlabel('Quantidade', fontsize=13);
ax.set_title('Pedidos por País', fontsize=20);

# %% [markdown]
# ##Produtos mais Vendidos
# > Foco nos produtos que possuem maior quantidade de vendas <br>
# > Criação de estratégia de aumento de estoque para produtos com mais saída, e redução de estoque para produtos com menos vendas

# %%
# Plotagem por nome do produto
fig, ax = plt.subplots(figsize=(15, 8))

graph = sns.barplot(data=df_produtos_10p, y='description', x='n', ax=ax);
ax.set_ylabel('Descrição', fontsize=13);
ax.set_xlabel('Quantidade', fontsize=13);
ax.set_title('Produtos Mais Vendidos', fontsize=20);

# %% [markdown]
# ##Análise de Vendas por Valor e por Cliente
# > Visualização dos outliers tanto por cliente, quanto por valor de pedido <br>
# > Criação de estratégias de brindes e descontos para os clientes que mais compram <br>
# > Desconto ou frete grátis para os clientes que possuem poucas compras

# %%
# Plotagem do gráfico
sns.lmplot(
    data=df_out, x="quantity", y="total_price",
    facet_kws=dict(sharex=False, sharey=False) 
)
plt.title('VALOR TOTAL POR VENDA')
plt.xlabel('Quantidade')
plt.ylabel('Valor');
# Existem alguns pedidos que os valores estão destuando dos valores médios

# %%
# Plotagem do gráfico de clientes
sns.lmplot(
    data = df_valor_cliente, x="customer_id", y="total_price",
    facet_kws=dict(sharex=False, sharey=False) 
)
plt.title('VALOR GASTO POR CLIENTE')
plt.xlabel('Cliente')
plt.ylabel('Valor');
